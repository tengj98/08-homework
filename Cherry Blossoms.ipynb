# %% [markdown]
# # Cherry Blossoms!
#
# If we travel back in time, [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were once in full bloom! We don't live in Japan or DC, but in non-COVID times we also have the [Brooklyn Botanic Garden's annual festival](https://www.bbg.org/visit/event/sakura_matsuri_2020).
#
# We'll have to make up for it with data-driven cherry blossoms instead. Once upon a time [Data is Plural](https://tinyletter.com/data-is-plural) linked to [a dataset](http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/) about when the cherry trees blossom each year. It's completely out of date, but it's quirky in a real nice way so we're sticking with it.
#
# ## 0. Do all of your importing/setup stuff

# %%
import pandas as pd

# %% [markdown]
# ## 1. Read in the file using pandas, and look at the first five rows
#
# * *Tip: You will probably need to pip install something to make this Excel file work!*

# %%
df = pd.read_excel("KyotoFullFlower7.xls")
df.head(50)
# Out:
#    Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0   This phenological data was acquired by followi...
# 1                                                 NaN
# 2                                      Column A; A.D.
# 3        Column B; Full-flowering date (day of year).
# 4   Column C; Full-flowering date (calender date, ...
# 5                               Column D; Source code
# 6    1; Reported by Taguchi (1939), J. Marine Mete...
# 7    2; Added by Sekiguchi (1969), Tokyo Geography...
# 8    3; Added by Aono and Omoto (1994), J. Agric. ...
# 9    4; Added by Aono and Kazui (2008), Int. J. Cl...
# 10   5: Cherry phenological data, Added by Aono an...
# 11   6: Added by Aono (2011), Time Studies, 4, 17-...
# 12   7: Added by Aono (2012), Chikyu Kankyo, 17, 2...
# 13   8: Found after the last publication of articles.
# 14                           Column E; Data type code
# 15   0 : data from modern times (full-bloom date s...
# 16        1 : from diary description about full-bloom
# 17   2 : from diary description about cherry bloss...
# 18   3 : from diary description about presents of ...
# 19                        4 : title in Japanese poety
# 20   8 : Deduced from wisteria phenology, using th...
# 21   9 : Deduced from Japanese kerria phenology, u...
# 22                   Column F; Names of old documents
# 23                                                NaN
# 24                                                 AD
# 25                                                801
# 26                                                802
# 27                                                803
# 28                                                804
# 29                                                805
# 30                                                806
# 31                                                807
# 32                                                808
# 33                                                809
# 34                                                810
# 35                                                811
# 36                                                812
# 37                                                813
# 38                                                814
# 39                                                815
# 40                                                816
# 41                                                817
# 42                                                818
# 43                                                819
# 44                                                820
# 45                                                821
# 46                                                822
# 47                                                823
# 48                                                824
# 49                                                825
#
#                    Unnamed: 1           Unnamed: 2   Unnamed: 3  \
# 0                         NaN                  NaN          NaN
# 1                         NaN                  NaN          NaN
# 2                         NaN                  NaN          NaN
# 3                         NaN                  NaN          NaN
# 4                         NaN                  NaN          NaN
# 5                         NaN                  NaN          NaN
# 6                         NaN                  NaN          NaN
# 7                         NaN                  NaN          NaN
# 8                         NaN                  NaN          NaN
# 9                         NaN                  NaN          NaN
# 10                        NaN                  NaN          NaN
# 11                        NaN                  NaN          NaN
# 12                        NaN                  NaN          NaN
# 13                        NaN                  NaN          NaN
# 14                        NaN                  NaN          NaN
# 15                        NaN                  NaN          NaN
# 16                        NaN                  NaN          NaN
# 17                        NaN                  NaN          NaN
# 18                        NaN                  NaN          NaN
# 19                        NaN                  NaN          NaN
# 20                        NaN                  NaN          NaN
# 21                        NaN                  NaN          NaN
# 22                        NaN                  NaN          NaN
# 23                        NaN                  NaN          NaN
# 24  Full-flowering date (DOY)  Full-flowering date  Source code
# 25                        NaN                  NaN          NaN
# 26                        NaN                  NaN          NaN
# 27                        NaN                  NaN          NaN
# 28                        NaN                  NaN          NaN
# 29                        NaN                  NaN          NaN
# 30                        NaN                  NaN          NaN
# 31                        NaN                  NaN          NaN
# 32                        NaN                  NaN          NaN
# 33                        NaN                  NaN          NaN
# 34                        NaN                  NaN          NaN
# 35                        NaN                  NaN          NaN
# 36                         92                  401            1
# 37                        NaN                  NaN          NaN
# 38                        NaN                  NaN          NaN
# 39                        105                  415            1
# 40                        NaN                  NaN          NaN
# 41                        NaN                  NaN          NaN
# 42                        NaN                  NaN          NaN
# 43                        NaN                  NaN          NaN
# 44                        NaN                  NaN          NaN
# 45                        NaN                  NaN          NaN
# 46                        NaN                  NaN          NaN
# 47                        NaN                  NaN          NaN
# 48                        NaN                  NaN          NaN
# 49                        NaN                  NaN          NaN
#
#         Unnamed: 4      Unnamed: 5
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# 5              NaN             NaN
# 6              NaN             NaN
# 7              NaN             NaN
# 8              NaN             NaN
# 9              NaN             NaN
# 10             NaN             NaN
# 11             NaN             NaN
# 12             NaN             NaN
# 13             NaN             NaN
# 14             NaN             NaN
# 15             NaN             NaN
# 16             NaN             NaN
# 17             NaN             NaN
# 18             NaN             NaN
# 19             NaN             NaN
# 20             NaN             NaN
# 21             NaN             NaN
# 22             NaN             NaN
# 23             NaN             NaN
# 24  Data type code  Reference Name
# 25             NaN               -
# 26             NaN               -
# 27             NaN               -
# 28             NaN               -
# 29             NaN               -
# 30             NaN               -
# 31             NaN               -
# 32             NaN               -
# 33             NaN               -
# 34             NaN               -
# 35             NaN               -
# 36               2      NIHON-KOKI
# 37             NaN               -
# 38             NaN               -
# 39               2      NIHON-KOKI
# 40             NaN               -
# 41             NaN               -
# 42             NaN               -
# 43             NaN               -
# 44             NaN               -
# 45             NaN               -
# 46             NaN               -
# 47             NaN               -
# 48             NaN               -
# 49             NaN               -

# %% [markdown]
# ## 2. Read in the file using pandas CORRECTLY, and look at the first five rows
#
# Hrm, how do your column names look? Read the file in again but this time add **a parameter to make sure your columns look right**. How can you tell pandas to skip rows?
#
# **TIP: The first year should be 801 AD, and it should not have any dates or anything.**

# %%
df = pd.read_excel("KyotoFullFlower7.xls",skiprows=25)
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0      801                        NaN                  NaN          NaN
# 1      802                        NaN                  NaN          NaN
# 2      803                        NaN                  NaN          NaN
# 3      804                        NaN                  NaN          NaN
# 4      805                        NaN                  NaN          NaN
# ...    ...                        ...                  ...          ...
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 0                NaN                       -
# 1                NaN                       -
# 2                NaN                       -
# 3                NaN                       -
# 4                NaN                       -
# ...              ...                     ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)
#
# [1215 rows x 6 columns]

# %% [markdown]
# ## 3. Look at the final five rows of the data

# %%
df.tail(5)
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## 4. Add some NaN values

# %% [markdown]
# It looks like you should have NaN/missing values in the beginning of the dataset under "Reference name." Read in the file *one more time*, this time making sure all of those missing reference names actually show up as `NaN` instead of `-`.
#
# * *Tip: it's another open with reading in the file!*

# %%
df = pd.read_excel("KyotoFullFlower7.xls",skiprows=25,na_values = "-")
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0      801                        NaN                  NaN          NaN
# 1      802                        NaN                  NaN          NaN
# 2      803                        NaN                  NaN          NaN
# 3      804                        NaN                  NaN          NaN
# 4      805                        NaN                  NaN          NaN
# ...    ...                        ...                  ...          ...
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 0                NaN                     NaN
# 1                NaN                     NaN
# 2                NaN                     NaN
# 3                NaN                     NaN
# 4                NaN                     NaN
# ...              ...                     ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)
#
# [1215 rows x 6 columns]

# %% [markdown]
# ## 5. What reference is the most commonly used when figuring out cherry blossom flowering dates?
#
# If the first result is `"-"`, you need to redo the last question.

# %%
df['Reference Name'].value_counts()

# NEWS-PAPER(ARASHIYAMA)
# Out:
# NEWS-PAPER(ARASHIYAMA)        94
# SUGIURAKE-NIKKI               38
# MYOHOIN-HINAMIKI              32
# OYUDONONO-UENO-NIKKI          26
# OYUDONONO-UENO-NIKKI [EDA]    21
#                               ..
# GONARAIN-GYOSEI-BASSHO         1
# MORIMITSU-KOKI                 1
# SANKAIKI                       1
# TSUKIMOUDE-WAKASHU(PART-3)     1
# NEWS-PAPET(DAIGO-JI)           1
# Name: Reference Name, Length: 222, dtype: int64

# %% [markdown]
# ## 6. Filter the list to only include columns where the `Full-flowering date (DOY)` is not missing

# %%
df = df.dropna(subset=['Full-flowering date (DOY)'])
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11     812                       92.0                401.0          1.0
# 14     815                      105.0                415.0          1.0
# 30     831                       96.0                406.0          1.0
# 50     851                      108.0                418.0          1.0
# 52     853                      104.0                414.0          1.0
# ...    ...                        ...                  ...          ...
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 11               2.0              NIHON-KOKI
# 14               2.0              NIHON-KOKI
# 30               2.0              NIHON-KOKI
# 50               2.0  MONTOKUTENNO-JITSUROKU
# 52               2.0  MONTOKUTENNO-JITSUROKU
# ...              ...                     ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)
#
# [827 rows x 6 columns]

# %% [markdown]
# ## 6.5 Confirm you now have 827 rows

# %%
df.shape
# Out:
# (827, 6)

# %% [markdown]
# ## 7. Make a histogram of the full-flowering date

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('-','')
df
# Out:
#         ad  fullflowering_date_(doy)  fullflowering_date  source_code  \
# 11     812                      92.0               401.0          1.0
# 14     815                     105.0               415.0          1.0
# 30     831                      96.0               406.0          1.0
# 50     851                     108.0               418.0          1.0
# 52     853                     104.0               414.0          1.0
# ...    ...                       ...                 ...          ...
# 1210  2011                      99.0               409.0          8.0
# 1211  2012                     101.0               410.0          8.0
# 1212  2013                      93.0               403.0          8.0
# 1213  2014                      94.0               404.0          8.0
# 1214  2015                      93.0               403.0          8.0
#
#       data_type_code          reference_name
# 11               2.0              NIHON-KOKI
# 14               2.0              NIHON-KOKI
# 30               2.0              NIHON-KOKI
# 50               2.0  MONTOKUTENNO-JITSUROKU
# 52               2.0  MONTOKUTENNO-JITSUROKU
# ...              ...                     ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)
#
# [827 rows x 6 columns]

# %%
df['fullflowering_date'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 8. Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df['fullflowering_date'].hist(bins=39)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 9. What's the average number of days it takes for the flowers to blossom? And how many records do we have?
#
# Answer these both with one line of code.

# %%
df['fullflowering_date'].describe()

# 827 records and 413 days to blossom
# Out:
# count    827.000000
# mean     413.717050
# std       12.381731
# min      327.000000
# 25%      410.000000
# 50%      414.000000
# 75%      419.000000
# max      504.000000
# Name: fullflowering_date, dtype: float64

# %% [markdown]
# ## 10. What's the average days into the year cherry flowers normally blossomed before 1900?

# %%
df.query("ad < 1900").fullflowering_date.describe()
# Out:
# count    714.000000
# mean     414.389356
# std       12.716664
# min      327.000000
# 25%      411.000000
# 50%      415.000000
# 75%      419.000000
# max      504.000000
# Name: fullflowering_date, dtype: float64

# %% [markdown]
# ## 11. How about after 1900?

# %%
df.query("ad > 1900").fullflowering_date.describe()
# Out:
# count    112.000000
# mean     409.446429
# std        8.985313
# min      329.000000
# 25%      407.000000
# 50%      409.000000
# 75%      413.250000
# max      421.000000
# Name: fullflowering_date, dtype: float64

# %% [markdown]
# ## 12. How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
df[df['data_type_code'] == 4.0].shape

#39 times
# Out:
# (39, 6)

# %% [markdown]
# ## 13. Display the rows where our data was from a title in Japanese poetry

# %%
df[df['data_type_code'] == 4.0]
# Out:
#         ad  fullflowering_date_(doy)  fullflowering_date  source_code  \
# 90     891                     109.0               419.0          5.0
# 94     895                     104.0               414.0          5.0
# 95     896                     104.0               413.0          5.0
# 122    923                     104.0               414.0          5.0
# 154    955                      89.0               330.0          5.0
# 168    969                      98.0               408.0          5.0
# 206   1007                     106.0               416.0          5.0
# 232   1033                     102.0               412.0          5.0
# 235   1036                     104.0               413.0          5.0
# 259   1060                     108.0               417.0          5.0
# 260   1061                      92.0               402.0          6.0
# 283   1084                     120.0               429.0          5.0
# 294   1095                     100.0               410.0          5.0
# 381   1182                     104.0               414.0          6.0
# 389   1190                     112.0               422.0          5.0
# 400   1201                      96.0               406.0          5.0
# 415   1216                     101.0               410.0          5.0
# 418   1219                     101.0               411.0          5.0
# 420   1221                      99.0               409.0          5.0
# 422   1223                     116.0               426.0          5.0
# 435   1236                      87.0               327.0          7.0
# 464   1265                      98.0               408.0          6.0
# 467   1268                     103.0               412.0          6.0
# 468   1269                     100.0               410.0          3.0
# 470   1271                     100.0               410.0          5.0
# 488   1289                     107.0               417.0          3.0
# 500   1301                      95.0               405.0          4.0
# 523   1324                      98.0               407.0          5.0
# 529   1330                     108.0               418.0          7.0
# 646   1447                     111.0               421.0          3.0
# 652   1453                     107.0               417.0          3.0
# 653   1454                     105.0               415.0          3.0
# 673   1474                      98.0               408.0          3.0
# 733   1534                     108.0               418.0          3.0
# 791   1592                      98.0               407.0          4.0
# 839   1640                     103.0               412.0          3.0
# 860   1661                      93.0               403.0          7.0
# 1045  1846                      98.0               408.0          4.0
# 1062  1863                     118.0               428.0          4.0
#
#       data_type_code              reference_name
# 90               4.0                NIHONKIRYAKU
# 94               4.0                NIHONKIRYAKU
# 95               4.0     NIPPON-SANDAI-JITSUROKU
# 122              4.0          ZOKU-KOKIN-WAKASHU
# 154              4.0                     SHUISHO
# 168              4.0                NIHONKIRYAKU
# 206              4.0              MIDO-KAMPAKUKI
# 232              4.0                NIHONKIRYAKU
# 235              4.0                NIHONKIRYAKU
# 259              4.0         SHIN-SENZAI-WAKASHU
# 260              4.0                MOROZANE-SHU
# 283              4.0          ZOKU-GOSEN-WAKASHU
# 294              4.0                     CHUYUKI
# 381              4.0  TSUKIMOUDE-WAKASHU(PART-3)
# 389              4.0                SHUGYOKU-SHU
# 400              4.0           INOKUMA-KAMPAKUKI
# 415              4.0            JUNTOKUIN-GYOSHU
# 418              4.0            JUNTOKUIN-GYOSHU
# 420              4.0                   SHUI-GUSO
# 422              4.0              MITSUTSUNE-SHU
# 435              4.0              SHIIBA-WAKASHU
# 464              4.0                  TAMEIE-SHU
# 467              4.0                  TAMEIE-SHU
# 468              4.0               ZOKU-SHIGUSHO
# 470              4.0         DAINAGON-TAMEIE-SHU
# 488              4.0         NAKANOTSUKASA-NIKKI
# 500              4.0                SANEMI-KYOKI
# 523              4.0        HANAZONOTENNO-SHINKI
# 529              4.0               RINEI-WAKASHU
# 646              4.0                    SOKONSHU
# 652              4.0                    SOKONSHU
# 653              4.0                    SOKONSHU
# 673              4.0              ENROKUCHOKASHU
# 733              4.0      GONARAIN-GYOSEI-BASSHO
# 791              4.0             TOKITSUNE-KYOKI
# 839              4.0                  KYOHAKUSHU
# 860              4.0         BURUI-GENYO-WAKASHU
# 1045             4.0                  TEIEN-EISO
# 1062             4.0                  YATAKA-SHU

# %% [markdown]
# ## 14. Graph the full-flowering date (DOY) over time

# %%
df.plot(x='ad',y='fullflowering_date_(doy)')
# Out:
# <AxesSubplot:xlabel='ad'>

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
df.rolling(10, on='ad', min_periods=5)['fullflowering_date_(doy)'].mean().tail()
# Out:
# 1210    95.9
# 1211    96.9
# 1212    96.4
# 1213    96.6
# 1214    96.0
# Name: fullflowering_date_(doy), dtype: float64

# %%
df['rolling_date'] = df.rolling(20, on='ad', min_periods=5)['fullflowering_date_(doy)'].mean()
df.plot(x='ad',y='rolling_date',ylim=(80, 120))
# Out:
# /var/folders/x3/wb71k0516kb6v12kvs75x8lw0000gn/T/ipykernel_6334/711611435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rolling_date'] = df.rolling(20, on='ad', min_periods=5)['fullflowering_date_(doy)'].mean()
# <AxesSubplot:xlabel='ad'>

# %% [markdown]
# Use the code above to create a new column called `rolling_date` in our dataset. It should be the 20-year rolling average of the flowering date. Then plot it, with the year on the x axis and the day of the year on the y axis.
#
# Try adding `ylim=(80, 120)` to your `.plot` command to make things look a little less dire.

# %% [markdown]
# ## 16. Add a month column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.
#
# There are **at least two ways to do this.**
#
# #### WAY ONE: The bad-yet-simple way
#
# If you don't want to use `pd.to_datetime`, you can use this as an sample for updating March. It finds everything with a date less than 400 and assigns `March` to the `month` column:
#
# ```python
# df.loc[df['Full-flowering date'] < 400, 'month'] = 'March'
# ```
#
# #### WAY TWO: The good-yet-complicated way
#
# * When you use `pd.to_datetime`, if pandas doesn't figure it out automatically you can also pass a `format=` argument that explains what the format is of the datetime. You use [the codes here](https://strftime.org/) to mark out where the days, months, etc are. For example, `2020-04-09` would be converted using `pd.to_datetime(df.colname, "format='%Y-%m-%d")`.
# * `errors='coerce'` will return `NaN` for missing values. By default it just yells "I don't know what to do!!!"
# * And remember how we used `df.date_column.dt.month` to get the number of the month? For the name, you use `dt.strftime` (string-formatted-time), and pass it [the same codes](https://strftime.org/) to tell it what to do. For example, `df.date_column.dt.strftime("%Y-%m-%d")` would give you `"2020-04-09"`.

# %%
df['fullflowering_date'] = df['fullflowering_date'].astype(int)

df['month'] = pd.to_datetime(df.fullflowering_date, format='%m%d', errors='coerce')
df['month'] = df.month.dt.strftime("%m")

df
# Out:
# /var/folders/x3/wb71k0516kb6v12kvs75x8lw0000gn/T/ipykernel_6334/3177274109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fullflowering_date'] = df['fullflowering_date'].astype(int)
# /var/folders/x3/wb71k0516kb6v12kvs75x8lw0000gn/T/ipykernel_6334/3177274109.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = pd.to_datetime(df.fullflowering_date, format='%m%d', errors='coerce')
# /var/folders/x3/wb71k0516kb6v12kvs75x8lw0000gn/T/ipykernel_6334/3177274109.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.month.dt.strftime("%m")
#         ad  fullflowering_date_(doy)  fullflowering_date  source_code  \
# 11     812                      92.0                 401          1.0
# 14     815                     105.0                 415          1.0
# 30     831                      96.0                 406          1.0
# 50     851                     108.0                 418          1.0
# 52     853                     104.0                 414          1.0
# ...    ...                       ...                 ...          ...
# 1210  2011                      99.0                 409          8.0
# 1211  2012                     101.0                 410          8.0
# 1212  2013                      93.0                 403          8.0
# 1213  2014                      94.0                 404          8.0
# 1214  2015                      93.0                 403          8.0
#
#       data_type_code          reference_name  rolling_date month day_of_month
# 11               2.0              NIHON-KOKI           NaN    04   1900-04-01
# 14               2.0              NIHON-KOKI           NaN    04   1900-04-15
# 30               2.0              NIHON-KOKI           NaN    04   1900-04-06
# 50               2.0  MONTOKUTENNO-JITSUROKU           NaN    04   1900-04-18
# 52               2.0  MONTOKUTENNO-JITSUROKU        101.00    04   1900-04-14
# ...              ...                     ...           ...   ...          ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)         96.45    04   1900-04-09
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)         96.80    04   1900-04-10
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)         96.60    04   1900-04-03
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)         96.35    04   1900-04-04
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)         96.05    04   1900-04-03
#
# [827 rows x 9 columns]

# %% [markdown]
# ## 17. Using your new column, how many blossomings happened in each month?

# %%
df.month.value_counts()
# Out:
# 04    814
# 03     10
# 05      3
# Name: month, dtype: int64

# %% [markdown]
# ## 18. Make a bar graph of how many blossomings happened in each month.

# %%
df.month.value_counts().sort_index().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called `day_of_month.`
#
# *Tip: If you didn't drop the rows missing full-flowering dates earlier, it will yell at you about missing data. Go back up and fix Number 6!*

# %%
df['day_of_month'] = pd.to_datetime(df.fullflowering_date, format='%m%d', errors='coerce')
df['day_of_month'] = df.day_of_month.dt.strftime("%d")
df
# Out:
# /var/folders/x3/wb71k0516kb6v12kvs75x8lw0000gn/T/ipykernel_6334/1294883340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_month'] = pd.to_datetime(df.fullflowering_date, format='%m%d', errors='coerce')
# /var/folders/x3/wb71k0516kb6v12kvs75x8lw0000gn/T/ipykernel_6334/1294883340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day_of_month'] = df.day_of_month.dt.strftime("%d")
#         ad  fullflowering_date_(doy)  fullflowering_date  source_code  \
# 11     812                      92.0                 401          1.0
# 14     815                     105.0                 415          1.0
# 30     831                      96.0                 406          1.0
# 50     851                     108.0                 418          1.0
# 52     853                     104.0                 414          1.0
# ...    ...                       ...                 ...          ...
# 1210  2011                      99.0                 409          8.0
# 1211  2012                     101.0                 410          8.0
# 1212  2013                      93.0                 403          8.0
# 1213  2014                      94.0                 404          8.0
# 1214  2015                      93.0                 403          8.0
#
#       data_type_code          reference_name  rolling_date month day_of_month
# 11               2.0              NIHON-KOKI           NaN    04           01
# 14               2.0              NIHON-KOKI           NaN    04           15
# 30               2.0              NIHON-KOKI           NaN    04           06
# 50               2.0  MONTOKUTENNO-JITSUROKU           NaN    04           18
# 52               2.0  MONTOKUTENNO-JITSUROKU        101.00    04           14
# ...              ...                     ...           ...   ...          ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)         96.45    04           09
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)         96.80    04           10
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)         96.60    04           03
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)         96.35    04           04
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)         96.05    04           03
#
# [827 rows x 9 columns]

# %% [markdown]
# ## 20. Adding a date column
#
# If you don't have a nice-looking date column yet, take the `'month'` and `'day_of_month'` columns and combine them in order to create a new column called `'date'`. By "nice looking," I mean it should say something like `April 11`.
#
# * Instead of using the two existing columns, you could learn to use `.dt.strftime` as mentioned above.

# %%
df['date'] = pd.to_datetime(df.fullflowering_date, format='%m%d', errors='coerce')
df['date'] = df.date.dt.strftime("%B %d")

df
# Out:
# /var/folders/x3/wb71k0516kb6v12kvs75x8lw0000gn/T/ipykernel_6334/1139122002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df.fullflowering_date, format='%m%d', errors='coerce')
# /var/folders/x3/wb71k0516kb6v12kvs75x8lw0000gn/T/ipykernel_6334/1139122002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df.date.dt.strftime("%B %d")
#         ad  fullflowering_date_(doy)  fullflowering_date  source_code  \
# 11     812                      92.0                 401          1.0
# 14     815                     105.0                 415          1.0
# 30     831                      96.0                 406          1.0
# 50     851                     108.0                 418          1.0
# 52     853                     104.0                 414          1.0
# ...    ...                       ...                 ...          ...
# 1210  2011                      99.0                 409          8.0
# 1211  2012                     101.0                 410          8.0
# 1212  2013                      93.0                 403          8.0
# 1213  2014                      94.0                 404          8.0
# 1214  2015                      93.0                 403          8.0
#
#       data_type_code          reference_name  rolling_date month day_of_month  \
# 11               2.0              NIHON-KOKI           NaN    04           01
# 14               2.0              NIHON-KOKI           NaN    04           15
# 30               2.0              NIHON-KOKI           NaN    04           06
# 50               2.0  MONTOKUTENNO-JITSUROKU           NaN    04           18
# 52               2.0  MONTOKUTENNO-JITSUROKU        101.00    04           14
# ...              ...                     ...           ...   ...          ...
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)         96.45    04           09
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)         96.80    04           10
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)         96.60    04           03
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)         96.35    04           04
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)         96.05    04           03
#
#           date
# 11    April 01
# 14    April 15
# 30    April 06
# 50    April 18
# 52    April 14
# ...        ...
# 1210  April 09
# 1211  April 10
# 1212  April 03
# 1213  April 04
# 1214  April 03
#
# [827 rows x 10 columns]

# %% [markdown]
# ## 21. What day of the week do cherry blossoms like to blossom on?
#
# Do they get the weekends off?

# %%
SKIP!!

# %%
df.dtypes
# Out:
# ad                            int64
# fullflowering_date_(doy)    float64
# fullflowering_date            int64
# source_code                 float64
# data_type_code              float64
# reference_name               object
# rolling_date                float64
# month                        object
# day_of_month                 object
# date                         object
# dtype: object

# %% [markdown]
# # YOU ARE DONE.
#
# And **incredible.**
